# %% [markdown]
# # Courbes de niveau

# %% [markdown]
# ## Table des matières
#
# - Préambule
#
#   - Dépendances logicielles
#
#   - Différentiation automatique
#
# - Ensembles de niveau
#
#   - Exemples de référence
#
#   - Analyse des ensembles de niveau (Q1, Q2, Q3, Q4)
#
# - Construction des courbes de niveau
#
#   - Méthode de Newton (Q5, T1, T2)
#
#   - Génération des points (Q6, T3)
#
#   - Bouclage et auto-intersection (Q7, T4, T5)
#
# - Post-traitement
#
#   - Interpolation (Q8, T6)
#
#   - Intégration (T7, T8)

# %% [markdown]
# ## Préambule

# %% [markdown]
# ### Dépendances logicielles

# %%
# Python Standard Library
# -----------------------
pass

# %%
# Third-Party Libraries
# ---------------------

# Autograd & Numpy
import autograd
import autograd.numpy as np

# Pandas
import pandas as pd

# Matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 10] # [width, height] (inches). 

# Jupyter & IPython
from IPython.display import display

# %% [markdown]
# ### Différentation automatique

# %% [markdown]
# On définit ici deux fonctions utilitaires, `grad` et `J`, permettant de calculer simplement le gradient d'une fonction scalaire de deux variables réelles et la matrice jacobienne d'une fonction vectorielle de deux variables réelles.

# %%
def grad(f):
    g = autograd.grad
    def grad_f(x, y):
        return np.array([g(f, 0)(x, y), g(f, 1)(x, y)])
    return grad_f

# %%
def J(f):
    j = autograd.jacobian
    def J_f(x, y):
        return np.array([j(f, 0)(x, y), j(f, 1)(x, y)]).T
    return J_f

# %% [markdown]
# #### Exemples d'usage

# %%
def f(x, y):
    return np.sin(x) + 2.0 * np.sin(y)

grad_f = grad(f)

grad_f(0.0, 0.0) # array([1., 2.])
# Out:
# array([1., 2.])

# %%
def f(x, y):
    return np.array([x + 2 * y, 3 * x + 4 * y])

J_f = J(f)

J_f(0.0, 0.0) # array([[1., 2.], [3., 4.]])
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %% [markdown]
# #### Précautions
#
# Les deux sources d'erreurs (avec messages cryptiques) les plus communes avec autograd :

# %% [markdown]
# **Selection de NumPy**
#
# N'importez pas NumPy directement, par exemple avec
#
#     >>> import numpy as np # Wrong !
#
# mais importez le module `numpy` qui a été modifié par `autograd` (pour que les fonctions du module "coopérent" avec les algorithmes de différentiation automatique).
#
#     >>> import autograd.numpy as np # Right !
#
# Utilisez-le ensuite comme vous le feriez avec NumPy classique.

# %% [markdown]
# **Utilisez des doubles**
#
# Les fonctions générées par autograd sont strictes quand au type des nombres utilisés (plus strictes que les fonctions NumPy) : il doit s'agir de doubles. Par exemple, si l'on définit
#
#     >>> def add(x, y):
#     ...    return x + y
#     >>> grad_add = grad(add)
#
# Alors `grad_add(0.0, 0.0)` renvoie `array([1.0, 1.0])`, mais `grad_add(0, 0)` génère une erreur, car ses arguments sont des entiers et non des doubles.

# %% [markdown]
# ## Ensembles de niveau

# %% [markdown]
# On appelle *ensemble de niveau* $c \in \mathbb{R}$ d'une fonction $f : \mathbb{R}^2 \to \mathbb{R}$  l'ensemble du plan
# $$
# \{(x_1,x_2) \in \mathbb{R}^2 \; | \; f(x_1, x_2) = c\}.
# $$

# %% [markdown]
# ### Exemples de référence

# %% [markdown]
# On définit ici quelques fonctions qui pourront servir de référence pour valider les algorithmes de génération de courbes de niveau. On pourra également utiliser la fonction utilitaire `display_contour` ci-dessous, qui exploite [la fonction `contour` de Matplotlib](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.contour.html) pour représenter une collection d'ensembles de niveau.

# %%
def display_contour(f, x, y, levels):
    X, Y = np.meshgrid(x, y)
    Z = f(X, Y)
    fig, ax = plt.subplots()
    contour_set = plt.contour(
        X, Y, Z, colors="grey", linestyles="dashed", 
        levels=levels 
    )
    ax.clabel(contour_set)
    plt.grid(True)
    plt.xlabel("$x_1$") 
    plt.ylabel("$x_2$")
    plt.gca().set_aspect("equal")

# %% [markdown]
# #### Fonction quadratique

# %%
def f1(x1, x2):
    x1 = np.array(x1)
    x2 = np.array(x2)
    return 3.0 * x1 * x1 - 2.0 * x1 * x2 + 3.0 * x2 * x2 
print(f1(1,0))
print(f1(0,0))
print(f1(1,1))
# Out:
# 3.0
# 0.0
# 4.0

# %%
display_contour(
    f1, 
    x=np.linspace(-1.0, 1.5, 100), 
    y=np.linspace(-1.0, 1.5, 100), 
    levels=15 # 10 levels, automatically selected
)

# %% [markdown]
# #### Fonction de Rosenbrock
#
# Source : [Fonction de Rosenbrock, Wikipédia](https://en.wikipedia.org/wiki/Rosenbrock_function)
#
# $$
# f_2 : (x_1,x_2) \in \mathbb{R}^2 \mapsto (x_1 - 1)^2 + (x_1 - x_2^2)^2
# $$

# %%
def f2(x1, x2):
    return (x1 - 1)**2 + (x1 - x2**2)**2

# %%
display_contour(
    f2, 
    x=np.linspace(-1.0, 3.0, 100), 
    y=np.linspace(-2.0, 2.0, 100), 
    levels=[2**i for i in range(-3, 8)] # levels: [0.125, 0.25, ..., 64, 128]
)

# %% [markdown]
# #### Fonction complexe
#
# Source: [Courbe implicite, Wikipédia](https://en.wikipedia.org/wiki/Implicit_curve)

# %%
def f3(x, y):
    return np.sin(x + y) - np.cos(x * y) - 1 + 0.001 * (x * x + y * y)

# %%
display_contour(
    f3, 
    x=np.linspace(-5.0, 5.0, 100), 
    y=np.linspace(-5.0, 5.0, 100), 
    levels=5, # 5 levels, automatically selected
)

# %% [markdown]
# ### Analyse des ensembles de niveau

# %% [markdown]
# #### Question 1
#
# Soit $c \in \mathbb{R}$.
# On suppose que la fonction $f:\mathbb{R}^2 \to \mathbb{R}$ est continue et vérifie
# $f(x_1, x_2) \to +\infty$ quand $\|(x_1,x_2)\| \to +\infty$.
# Que peut-on dire de l'ensemble de niveau $c$ de $f$ ?

# %% [markdown]
# Dans la suite la fonction $f$ est supposée continûment différentiable. On suppose également que le gradient $\nabla f$ ne s'annule pas dans un voisinage du point $x_0 = (x_{10}, x_{20}) \in \mathbb{R}^2$. On pose alors
# $$
# p(x_1, x_2) := \frac{\partial_2 f(x_0)}{\|\nabla f(x_0)\|} (x_1 - x_{10}) -
# \frac{\partial_1 f(x_0)}{\|\nabla f(x_0)\|} (x_2 - x_{20}).
# $$

# %% [markdown]
# #### Question 2
# Comment interpréter géométriquement le terme $p(x_1,x_2)$ ?

# %% [markdown]
# #### Question 3
#
# Montrer que dans un voisinage ouvert de $x_0$, on peut paramétriser l'ensemble de niveau $c:=f(x_0)$ au moyen de $p(x_1,x_2),$ c'est-à-dire qu'il existe un $\varepsilon > 0$ et une fonction (continûment différentiable) $\gamma :\left]-\varepsilon,\varepsilon \right[ \to \mathbb{R}^2$ tels que dans un voisinage ouvert de $x_0,$ $f(x_1,x_2) = c$ si et seulement si $(x_1, x_2) = \gamma(t)$ où $t = p(x_1, x_2)$.

# %% [markdown]
# #### Question 4
#
# Montrer que pour tout $t \in \left]-\varepsilon, \varepsilon \right[$ :
#
#   - le vecteur $\gamma'(t)$ est non nul (il fournit donc une tangente au chemin $\gamma$),
#
#   - est orthogonal à $\nabla f(\gamma(t))$.

# %% [markdown]
# ## Construction des courbes de niveau

# %% [markdown]
# ### Méthode de Newton
#
# Afin de trouver des points sur des courbes de niveau, on souhaite implémenter un algorithme de résolution des équations de la forme $F(x) = 0$ où $F: \mathbb{R}^2 \to \mathbb{R}^2$, par la méthode de Newton, amorcée par un point de référence $x_0 \in \mathbb{R}^2$.
#
# L'implémentation prendra la forme générale donnée ci-dessous. L'appel `x, y = Newton(F, x0, y0, eps, N)` devra renvoyer le couple des coordonnées d'un point $(x, y)$ qui est une solution approchée de $F(x,y)=0$ à proximité de $(x_0, y_0)$. La qualité de l'approximation produite est déterminée par le réel positif $\varepsilon > 0$, une approximation de la distance entre le point $(x,y)$ renvoyé par la fonction et la solution exacte. L'algorithme itératif s'interrompra si aucune approximation de la précision souhaitée n'a été trouvée en $N$ étapes.

# %% [markdown]
# #### Question 5
#
# L'application à laquelle nous destinons la fonction `Newton` demande-t'elle une grande précision ?
# Choisir une valeur de `eps` qui semble raisonnable et justifier l'ordre de grandeur choisi.

# %%
N = 100
eps = 1e-6 #pas 10
print(eps)
#eps = ...
# Out:
# 1e-06

# %% [markdown]
# #### Tâche 1
#
# Implémenter la fonction `Newton` en complétant le canevas ci-dessous

# %%
def Newton(F, x0, y0, eps=eps, N=N):
    #
    j = J(F) # pas bonne fonction
    for i in range(N):
        #
        #calcul du jacobien
        print(j(x0,y0))
        ji = np.linalg.inv(j(x0,y0))
        #print (ji)
        #print(F(x0,y0).reshape(2,1))
        #print(np.dot(ji, F(x0,y0).reshape(2,1)))
        #print(np.array([x0,y0]).reshape(2,1))
        x,y = ((np.array([x0,y0]).reshape(2,1) - np.dot(ji, F(x0,y0).reshape(2,1))).reshape(2))
        print("p", x,y)
        if np.sqrt((x - x0)**2 + (y - y0)**2) <= eps:
            return x, y
        x0, y0 = x, y
    else:
        raise ValueError(f"no convergence in {N} steps.")

# %%
def f1bis(x,y):
    return np.array([f1(x,y)-0.8,x-y])

xs, ys = Newton(f1bis, 0.8, 0.8)

print(f1(xs,ys))
# Out:
# [[ 3.2  3.2]
#  [ 1.  -1. ]]
# p 0.525 0.525
# [[ 2.1  2.1]
#  [ 1.  -1. ]]
# p 0.4529761904761905 0.4529761904761905
# [[ 1.81190476  1.81190476]
#  [ 1.         -1.        ]]
# p 0.447250250297228 0.447250250297228
# [[ 1.789001  1.789001]
#  [ 1.       -1.      ]]
# p 0.4472135970019964 0.4472135970019964
# [[ 1.78885439  1.78885439]
#  [ 1.         -1.        ]]
# p 0.4472135954999579 0.4472135954999579
# 0.8

# %% [markdown]
# #### Tâche 2
#
# Testez votre implémentation de la fonction `Newton` ! On suggère par exemple de l'utiliser pour chercher un point $(x_1, x_2)$ de la ligne de niveau $0.8$ de $f_1$ (cf. Exemples de référence) qui vérifie en outre $x_1 = x_2$ en utilisant le point initial $(0.8, 0.8)$. Puis de faire varier le point initial, la contrainte supplémentaire, etc. et de représenter graphiquement les résultats.

# %% [markdown]
# ### Génération des points
#
# #### Question 6 + Tâche 3
# Comment, en partant d'un point de référence $(x_0, y_0)$ tel que $f(x_0, y_0)=c$, peut-on générer avec la méthode de Newton un point $(x_1, y_1)$ également tel que $f(x_1, y_1) = c$, mais à une distance $\delta > 0$ de $(x_0, y_0)$ et qui soit "à droite" quand on est en $(x_0, y_0)$ et qu'on regarde dans la direction de $\nabla f(x_0, y_0)$ ? Implémenter la fonction `level_curve` qui répète ce procédé $N-1$ fois et renvoie un tableau NumPy de taille `(2, N)` contenant les coordonnées des points correspondants, puis valider graphiquement le résultat au moyen des exemples de référence.

# %% [markdown]
# ![g%C3%A9n%C3%A9ration-points.png](attachment:g%C3%A9n%C3%A9ration-points.png)

# %%
def level_curve(f, x0, y0, delta=0.1, N=1000, eps=eps):
    gx,gy = grad(f)(x0,y0)
    print("g", gx,gy)
    #lagragien, problème de dimension sinon
    def fbis(x,y):
        d = np.linalg.det(np.array([[x-x0,gx],[y-y0,gy]]))
        print("d", d, "fin")
        return np.array([f(x,y)-0.8,((x-x0)**2+(y-y0)**2-delta**2)**2+(1-d/(np.abs(d)+eps/100))**2])
    print("fb", fbis(x0,y0))
    return (Newton(fbis, x0+0.1, y0))
#https://zestedesavoir.com/forums/sujet/11587/savoir-si-le-point-est-a-gauche-ou-a-droite-dun-vecteur/
#(f(x,y)-c, (x,y)-(x0,y0)=d) #deux points possibles
#det sur valeur absolue
#ou utilier p premières questions ?
#produit vectoriel signe sur norme, donne 1 ou -1? mais fonction suffisamment régulière ? mais comment le corriger?

#dichotomie, enlever mauvais point..., plus proche du reste

# %%
xa, ya= level_curve(f1, xs, ys) #partir d'un bon point
plt.close()
display_contour(
    f1, 
    x=np.linspace(-1.0, 1.5, 100), 
    y=np.linspace(-1.0, 1.5, 100), 
    levels=15 # 10 levels, automatically selected
)
plt.plot([xs], [ys],'+',color='r')
plt.plot([xa], [ya],'+',color='b')
# Out:
# g 1.788854381999832 1.788854381999832
# d 0.0 fin
# fb [0.     1.0001]
# d Autograd ArrayBox with value -0.17888543819998323 fin
# d Autograd ArrayBox with value -0.17888543819998323 fin
# [[ 1.58885438e+00  2.38885438e+00]
#  [-2.23606766e-06  2.23606766e-06]]
# d Autograd ArrayBox with value -0.17888543819998323 fin
# d Autograd ArrayBox with value -0.17888543819998323 fin
# d -0.17888543819998323 fin
# p 1074315.597186628 -714538.8384562581
# d Autograd ArrayBox with value 3200000.0959596126 fin
# d Autograd ArrayBox with value 3200000.0959596126 fin
# [[ 7.87497126e+06 -6.43586423e+06]
#  [ 7.15373323e+18 -4.75802974e+18]]
# d Autograd ArrayBox with value 3200000.0959596126 fin
# d Autograd ArrayBox with value 3200000.0959596126 fin
# d 3200000.0959596126 fin
# p 2618061.926600145 2188940.3250666866
# d Autograd ArrayBox with value 767636.0573139122 fin
# d Autograd ArrayBox with value 767636.0573139122 fin
# [[1.13304909e+07 7.89751810e+06]
#  [1.21956673e+20 1.01966981e+20]]
# d Autograd ArrayBox with value 767636.0573139122 fin
# d Autograd ArrayBox with value 767636.0573139122 fin
# d 767636.0573139122 fin
# p -4264263.613569611 9090420.632263482
# d Autograd ArrayBox with value -23889585.43338268 fin
# d Autograd ArrayBox with value -23889585.43338268 fin
# [[-4.37664229e+07  6.30710510e+07]
#  [-1.71968707e+21  3.66597328e+21]]
# d Autograd ArrayBox with value -23889585.43338268 fin
# d Autograd ArrayBox with value -23889585.43338268 fin
# d -23889585.43338268 fin
# p 10200351.446409304 13102998.228303285
# d Autograd ArrayBox with value -5192412.415188761 fin
# d Autograd ArrayBox with value -5192412.415188761 fin
# [[3.49961122e+07 5.82172865e+07]
#  [1.12504042e+22 1.44518577e+22]]
# d Autograd ArrayBox with value -5192412.415188761 fin
# d Autograd ArrayBox with value -5192412.415188761 fin
# d -5192412.415188761 fin
# p 34765050.01076507 -11280923.735454028
# d Autograd ArrayBox with value 82369541.90937313 fin
# d Autograd ArrayBox with value 82369541.90937313 fin
# [[ 2.31152148e+08 -1.37215642e+08]
#  [ 1.85766058e+23 -6.02792990e+22]]
# d Autograd ArrayBox with value 82369541.90937313 fin
# d Autograd ArrayBox with value 82369541.90937313 fin
# d 82369541.90937313 fin
# p 38571557.59435913 30054378.022618465
# d Autograd ArrayBox with value 15235993.999187736 fin
# d Autograd ArrayBox with value 15235993.999187736 fin
# [[1.71320590e+08 1.03183153e+08]
#  [3.68903099e+23 2.87443750e+23]]
# d Autograd ArrayBox with value 15235993.999187736 fin
# d Autograd ArrayBox with value 15235993.999187736 fin
# d 15235993.999187736 fin
# p -33476055.74070911 102630526.75656933
# d Autograd ArrayBox with value -243474856.51927835 fin
# d Autograd ArrayBox with value -243474856.51927835 fin
# [[-4.06117388e+08  6.82735272e+08]
#  [-1.56047582e+24  4.78408966e+24]]
# d Autograd ArrayBox with value -243474856.51927835 fin
# d Autograd ArrayBox with value -243474856.51927835 fin
# d -243474856.51927835 fin
# p 88925653.3437225 114168114.21988314
# d Autograd ArrayBox with value -45155086.75077924 fin
# d Autograd ArrayBox with value -45155086.75077924 fin
# [[3.05217692e+08 5.07157379e+08]
#  [7.44917031e+24 9.56369390e+24]]
# d Autograd ArrayBox with value -45155086.75077924 fin
# d Autograd ArrayBox with value -45155086.75077924 fin
# d -45155086.75077924 fin
# p 303430366.5070351 -98767909.24988082
# d Autograd ArrayBox with value 719474148.0205376 fin
# d Autograd ArrayBox with value 719474148.0205376 fin
# [[ 2.01811802e+09 -1.19946819e+09]
#  [ 1.23587294e+26 -4.02282040e+25]]
# d Autograd ArrayBox with value 719474148.0205376 fin
# d Autograd ArrayBox with value 719474148.0205376 fin
# d 719474148.0205376 fin
# p 337185815.9096699 262672362.56026682
# d Autograd ArrayBox with value 133293717.54201974 fin
# d Autograd ArrayBox with value 133293717.54201974 fin
# [[1.49777017e+09 9.01662544e+08]
#  [2.46403315e+26 1.91951552e+26]]
# d Autograd ArrayBox with value 133293717.54201974 fin
# d Autograd ArrayBox with value 133293717.54201974 fin
# d 133293717.54201974 fin
# p -292075071.66886806 896561223.8990626
# d Autograd ArrayBox with value -2126297245.9307387 fin
# d Autograd ArrayBox with value -2126297245.9307387 fin
# [[-3.54557288e+09  5.96351749e+09]
#  [-1.03877069e+27  3.18863747e+27]]
# d Autograd ArrayBox with value -2126297245.9307387 fin
# d Autograd ArrayBox with value -2126297245.9307387 fin
# d -2126297245.9307387 fin
# p 776411477.6476017 996717035.694799
# d Autograd ArrayBox with value -394094562.8916471 fin
# d Autograd ArrayBox with value -394094562.8916471 fin
# [[2.66503479e+09 4.42747926e+09]
#  [4.95741719e+27 6.36407666e+27]]
# d Autograd ArrayBox with value -394094562.8916471 fin
# d Autograd ArrayBox with value -394094562.8916471 fin
# d -394094562.8916471 fin
# p 2649746459.4753656 -862931814.0330887
# d Autograd ArrayBox with value 6283669922.121197 fin
# d Autograd ArrayBox with value 6283669922.121197 fin
# [[ 1.76243424e+10 -1.04770838e+10]
#  [ 8.23096849e+28 -2.68054498e+28]]
# d Autograd ArrayBox with value 6283669922.121197 fin
# d Autograd ArrayBox with value 6283669922.121197 fin
# d 6283669922.121197 fin
# p 2945261835.2264233 2294319637.54212
# d Autograd ArrayBox with value 1164440802.756165 fin
# d Autograd ArrayBox with value 1164440802.756165 fin
# [[1.30829317e+10 7.87539415e+09]
#  [1.64209773e+29 1.27917221e+29]]
# d Autograd ArrayBox with value 1164440802.756165 fin
# d Autograd ArrayBox with value 1164440802.756165 fin
# d 1164440802.756165 fin
# p -2550446494.4304905 7830463043.592617
# d Autograd ArrayBox with value -18569935516.236465 fin
# d Autograd ArrayBox with value -18569935516.236465 fin
# [[-3.09636051e+10  5.20836713e+10]
#  [-6.91894600e+29  2.12427711e+30]]
# d Autograd ArrayBox with value -18569935516.236465 fin
# d Autograd ArrayBox with value -18569935516.236465 fin
# d -18569935516.236465 fin
# p 6780501990.008768 8704338907.637161
# d Autograd ArrayBox with value -3441464100.3525915 fin
# d Autograd ArrayBox with value -3441464100.3525915 fin
# [[2.32743341e+10 3.86650295e+10]
#  [3.30185286e+30 4.23869005e+30]]
# d Autograd ArrayBox with value -3441464100.3525915 fin
# d Autograd ArrayBox with value -3441464100.3525915 fin
# d -3441464100.3525915 fin
# p 23141257566.65203 -7536907901.101341
# d Autograd ArrayBox with value 54878770728.70646 fin
# d Autograd ArrayBox with value 54878770728.70646 fin
# [[ 1.53921361e+11 -9.15039625e+10]
#  [ 5.48283763e+31 -1.78571290e+31]]
# d Autograd ArrayBox with value 54878770728.70646 fin
# d Autograd ArrayBox with value 54878770728.70646 fin
# d 54878770728.70646 fin
# p 25723132988.719414 20037867122.8416
# d Autograd ArrayBox with value 10170112757.009583 fin
# d Autograd ArrayBox with value 10170112757.009583 fin
# [[1.14263064e+11 6.87809368e+10]
#  [1.09394896e+32 8.52166958e+31]]
# d Autograd ArrayBox with value 10170112757.009583 fin
# d Autograd ArrayBox with value 10170112757.009583 fin
# d 10170112757.009583 fin
# p -22273843067.910713 68388006877.49011
# d Autograd ArrayBox with value -162180847555.04132 fin
# d Autograd ArrayBox with value -162180847555.04132 fin
# [[-2.70419072e+11  4.54875727e+11]
#  [-4.60894243e+32  1.41509656e+33]]
# d Autograd ArrayBox with value -162180847555.04132 fin
# d Autograd ArrayBox with value -162180847555.04132 fin
# d -162180847555.04132 fin
# p 59217273415.40894 76018868945.7608
# d Autograd ArrayBox with value -30055607789.058655 fin
# d Autograd ArrayBox with value -30055607789.058655 fin
# [[2.03265903e+11 3.37678667e+11]
#  [2.19946074e+33 2.82350922e+33]]
# d Autograd ArrayBox with value -30055607789.058655 fin
# d Autograd ArrayBox with value -30055607789.058655 fin
# d -30055607789.058655 fin
# p 202104289146.21085 -65824440540.23682
# d Autograd ArrayBox with value 479285482163.25073 fin
# d Autograd ArrayBox with value 479285482163.25073 fin
# [[ 1.34427462e+12 -7.99155222e+11]
#  [ 3.65234793e+34 -1.18955298e+34]]
# d Autograd ArrayBox with value 479285482163.25073 fin
# d Autograd ArrayBox with value 479285482163.25073 fin
# d 479285482163.25073 fin
# p 224654528557.91193 175001765380.5409
# d Autograd ArrayBox with value 88821562988.23988 fin
# d Autograd ArrayBox with value 88821562988.23988 fin
# [[9.97923641e+11 6.00701535e+11]
#  [7.28736832e+34 5.67672652e+34]]
# d Autograd ArrayBox with value 88821562988.23988 fin
# d Autograd ArrayBox with value 88821562988.23988 fin
# d 88821562988.23988 fin
# p -194528458656.21857 597269149023.8861
# d Autograd ArrayBox with value -1416410620155.5378 fin
# d Autograd ArrayBox with value -1416410620155.5378 fin
# [[-2.36170905e+12  3.97267181e+12]
#  [-3.07021743e+35  9.42662152e+35]]
# d Autograd ArrayBox with value -1416410620155.5378 fin
# d Autograd ArrayBox with value -1416410620155.5378 fin
# d -1416410620155.5378 fin
# p 517175094785.48834 663911894486.1919
# d Autograd ArrayBox with value -262490767145.23502 fin
# d Autograd ArrayBox with value -262490767145.23502 fin
# [[1.77522678e+12 2.94912118e+12]
#  [1.46515515e+36 1.88085996e+36]]
# d Autograd ArrayBox with value -262490767145.23502 fin
# d Autograd ArrayBox with value -262490767145.23502 fin
# d -262490767145.23502 fin
# p 1765082645513.4778 -574880456182.814
# d Autograd ArrayBox with value 4185853248187.3174 fin
# d Autograd ArrayBox with value 4185853248187.3174 fin
# [[ 1.17402568e+13 -6.97944803e+12]
#  [ 2.43299294e+37 -7.92416206e+36]]
# d Autograd ArrayBox with value 4185853248187.3174 fin
# d Autograd ArrayBox with value 4185853248187.3174 fin
# d 4185853248187.3174 fin
# p 1962027659503.5845 1528383421389.3257
# d Autograd ArrayBox with value 775726395579.6707 fin
# d Autograd ArrayBox with value 775726395579.6707 fin
# [[8.71539911e+12 5.24624521e+12]
#  [4.85445544e+37 3.78153141e+37]]
# d Autograd ArrayBox with value 775726395579.6707 fin
# d Autograd ArrayBox with value 775726395579.6707 fin
# d 775726395579.6707 fin
# p -1698918587313.2065 5216267372805.646
# d Autograd ArrayBox with value -12370260707102.322 fin
# d Autograd ArrayBox with value -12370260707102.322 fin
# [[-2.06260463e+13  3.46954414e+13]
#  [-2.04521050e+38  6.27950326e+38]]
# d Autograd ArrayBox with value -12370260707102.322 fin
# d Autograd ArrayBox with value -12370260707102.322 fin
# d -12370260707102.322 fin
# p 4516762088872.086 5798291413919.326
# d Autograd ArrayBox with value -2292469348772.0425 fin
# d Autograd ArrayBox with value -2292469348772.0425 fin
# [[1.55039897e+13 2.57562243e+13]
#  [9.76005856e+38 1.25292550e+39]]
# d Autograd ArrayBox with value -2292469348772.0425 fin
# d Autograd ArrayBox with value -2292469348772.0425 fin
# d -2292469348772.0425 fin
# p 15415396803072.246 -5020735501323.207
# d Autograd ArrayBox with value 36557264823846.195 fin
# d Autograd ArrayBox with value 36557264823846.195 fin
# [[ 1.02533852e+14 -6.09552066e+13]
#  [ 1.62072699e+40 -5.27864553e+39]]
# d Autograd ArrayBox with value 36557264823846.195 fin
# d Autograd ArrayBox with value 36557264823846.195 fin
# d 36557264823846.195 fin
# p 17135424090696.822 13348179574791.05
# d Autograd ArrayBox with value 6774828947982.867 fin
# d Autograd ArrayBox with value 6774828947982.867 fin
# [[7.61161854e+13 4.58182293e+13]
#  [3.23377432e+40 2.51905060e+40]]
# d Autograd ArrayBox with value 6774828947982.867 fin
# d Autograd ArrayBox with value 6774828947982.867 fin
# d 6774828947982.867 fin
# p -14837550720392.08 45556415629608.06
# d Autograd ArrayBox with value -108036011351548.34 fin
# d Autograd ArrayBox with value -108036011351548.34 fin
# [[-1.80138136e+14  3.03013595e+14]
#  [-1.36240760e+41  4.18306282e+41]]
# d Autograd ArrayBox with value -108036011351548.34 fin
# d Autograd ArrayBox with value -108036011351548.34 fin
# d -108036011351548.34 fin
# p 39447264713983.92 50639535538294.59
# d Autograd ArrayBox with value -20021342708596.98 fin
# d Autograd ArrayBox with value -20021342708596.98 fin
# [[1.35404517e+14 2.24942684e+14]
#  [6.50161810e+41 8.34630546e+41]]
# d Autograd ArrayBox with value -20021342708596.98 fin
# d Autograd ArrayBox with value -20021342708596.98 fin
# d -20021342708596.98 fin
# p 134630790280339.3 -43848733198791.22
# d Autograd ArrayBox with value 319273877672885.56 fin
# d Autograd ArrayBox with value 319273877672885.56 fin
# [[ 8.95482208e+14 -5.32353980e+14]
#  [ 1.07963991e+43 -3.51634587e+42]]
# d Autograd ArrayBox with value 319273877672885.56 fin
# d Autograd ArrayBox with value 319273877672885.56 fin
# d 319273877672885.56 fin
# p 149652699455069.8 116576694497923.6
# d Autograd ArrayBox with value 59168156406639.01 fin
# d Autograd ArrayBox with value 59168156406639.01 fin
# [[6.64762808e+14 4.00154768e+14]
#  [2.15416418e+43 1.67805419e+43]]
# d Autograd ArrayBox with value 59168156406639.01 fin
# d Autograd ArrayBox with value 59168156406639.01 fin
# d 59168156406639.01 fin
# p -129584154997711.81 397868209571911.4
# d Autograd ArrayBox with value -943535473656544.4 fin
# d Autograd ArrayBox with value -943535473656544.4 fin
# [[-1.57324135e+15  2.64637757e+15]
#  [-9.07561629e+43  2.78652834e+44]]
# d Autograd ArrayBox with value -943535473656544.4 fin
# d Autograd ArrayBox with value -943535473656544.4 fin
# d -943535473656544.4 fin
# p 344513768979699.9 442261772782653.1
# d Autograd ArrayBox with value -174856944934648.6 fin
# d Autograd ArrayBox with value -174856944934648.6 fin
# [[1.18255907e+15 1.96454310e+15]
#  [4.33102333e+44 5.55985341e+44]]
# d Autograd ArrayBox with value -174856944934648.6 fin
# d Autograd ArrayBox with value -174856944934648.6 fin
# d -174856944934648.6 fin
# p 1175801705169954.5 -382954118878827.0
# d Autograd ArrayBox with value 2788387186317427.5 fin
# d Autograd ArrayBox with value 2788387186317427.5 fin
# [[ 7.82071847e+15 -4.64932812e+15]
#  [ 7.19197224e+45 -2.34239785e+45]]
# d Autograd ArrayBox with value 2788387186317427.5 fin
# d Autograd ArrayBox with value 2788387186317427.5 fin
# d 2788387186317427.5 fin
# p 1306995966758911.5 1018125767185248.5
# d Autograd ArrayBox with value 516746722336515.7 fin
# d Autograd ArrayBox with value 516746722336515.7 fin
# [[5.80572427e+15 3.49476267e+15]
#  [1.43498670e+46 1.11782819e+46]]
# d Autograd ArrayBox with value 516746722336515.7 fin
# d Autograd ArrayBox with value 516746722336515.7 fin
# d 516746722336515.7 fin
# p -1131726776347255.5 3474792945411417.0
# d Autograd ArrayBox with value -8240392990036664.0 fin
# d Autograd ArrayBox with value -8240392990036664.0 fin
# [[-1.37399465e+16  2.31122112e+16]
#  [-6.04568060e+46  1.85623321e+47]]
# d Autograd ArrayBox with value -8240392990036664.0 fin
# d Autograd ArrayBox with value -8240392990036664.0 fin
# d -8240392990036664.0 fin
# p 3008820467744525.5 3862505343988426.0
# d Autograd ArrayBox with value -1527117931715882.2 fin
# d Autograd ArrayBox with value -1527117931715882.2 fin
# [[1.03279121e+16 1.71573911e+16]
#  [2.88509153e+47 3.70367111e+47]]
# d Autograd ArrayBox with value -1527117931715882.2 fin
# d Autograd ArrayBox with value -1527117931715882.2 fin
# d -1527117931715882.2 fin
# p 1.026889650485718e+16 -3344540325485196.0
# d Autograd ArrayBox with value 2.4352456128035904e+16 fin
# d Autograd ArrayBox with value 2.4352456128035904e+16 fin
# [[ 6.83024597e+16 -4.06050350e+16]
#  [ 4.79089967e+48 -1.56037770e+48]]
# d Autograd ArrayBox with value 2.4352456128035904e+16 fin
# d Autograd ArrayBox with value 2.4352456128035904e+16 fin
# d 2.4352456128035904e+16 fin
# p 1.1414685200991636e+16 8891829372096216.0
# d Autograd ArrayBox with value 4513021704673362.0 fin
# d Autograd ArrayBox with value 4513021704673362.0 fin
# [[5.07044525e+16 3.05216058e+16]
#  [9.55909881e+48 7.44636177e+48]]
# d Autograd ArrayBox with value 4513021704673362.0 fin
# d Autograd ArrayBox with value 4513021704673362.0 fin
# d 4513021704673362.0 fin
# p -9883966901424200.0 3.034719969197088e+16
# d Autograd ArrayBox with value -7.196769865355993e+16 fin
# d Autograd ArrayBox with value -7.196769865355993e+16 fin
# [[-1.19998201e+17  2.01851132e+17]
#  [-4.02730269e+49  1.23652133e+50]]
# d Autograd ArrayBox with value -7.196769865355993e+16 fin
# d Autograd ArrayBox with value -7.196769865355993e+16 fin
# d -7.196769865355993e+16 fin
# p 2.627761624557411e+16 3.3733296572666476e+16
# d Autograd ArrayBox with value -1.3337126423909096e+16 fin
# d Autograd ArrayBox with value -1.3337126423909096e+16 fin
# [[9.01991043e+16 1.49844547e+17]
#  [1.92189063e+50 2.46718370e+50]]
# d Autograd ArrayBox with value -1.3337126423909096e+16 fin
# d Autograd ArrayBox with value -1.3337126423909096e+16 fin
# d -1.3337126423909096e+16 fin
# p 8.968368984875322e+16 -2.9209634857453596e+16
# d Autograd ArrayBox with value 2.1268284489122608e+17 fin
# d Autograd ArrayBox with value 2.1268284489122608e+17 fin
# [[ 5.96521409e+17 -3.54625189e+17]
#  [ 3.19143607e+51 -1.03943853e+51]]
# d Autograd ArrayBox with value 2.1268284489122608e+17 fin
# d Autograd ArrayBox with value 2.1268284489122608e+17 fin
# d 2.1268284489122608e+17 fin
# p 9.96904669264047e+16 7.765703620500408e+16
# d Autograd ArrayBox with value 3.941459909646715e+16 fin
# d Autograd ArrayBox with value 3.941459909646715e+16 fin
# [[4.42828729e+17 2.66561283e+17]
#  [6.36775029e+51 4.96036011e+51]]
# d Autograd ArrayBox with value 3.941459909646715e+16 fin
# d Autograd ArrayBox with value 3.941459909646715e+16 fin
# d 3.941459909646715e+16 fin
# p -8.632189657620189e+16 2.6503810256720224e+17
# d Autograd ArrayBox with value -6.285318741271365e+17 fin
# d Autograd ArrayBox with value -6.285318741271365e+17 fin
# [[-1.04800758e+18  1.76287241e+18]
#  [-2.68276941e+52  8.23703073e+52]]
# d Autograd ArrayBox with value -6.285318741271365e+17 fin
# d Autograd ArrayBox with value -6.285318741271365e+17 fin
# d -6.285318741271365e+17 fin
# p 2.294962836825578e+17 2.946106727260901e+17
# d Autograd ArrayBox with value -1.1648016017176502e+17 fin
# d Autograd ArrayBox with value -1.1648016017176502e+17 fin
# [[7.87756357e+17 1.30867147e+18]
#  [1.28025872e+53 1.64350323e+53]]
# d Autograd ArrayBox with value -1.1648016017176502e+17 fin
# d Autograd ArrayBox with value -1.1648016017176502e+17 fin
# d -1.1648016017176502e+17 fin
# p 7.832549701280995e+17 -2.551031488224414e+17
# d Autograd ArrayBox with value 1.8574714711697746e+18 fin
# d Autograd ArrayBox with value 1.8574714711697746e+18 fin
# [[ 5.20973612e+18 -3.09712883e+18]
#  [ 2.12596066e+54 -6.92417257e+53]]
# d Autograd ArrayBox with value 1.8574714711697746e+18 fin
# d Autograd ArrayBox with value 1.8574714711697746e+18 fin
# d 1.8574714711697746e+18 fin
# p 8.706494327720243e+17 6.782198600033805e+17
# d Autograd ArrayBox with value 3.4422848447354477e+17 fin
# d Autograd ArrayBox with value 3.4422848447354477e+17 fin
# [[3.86745688e+18 2.32802029e+18]
#  [4.24184796e+54 3.30432138e+54]]
# d Autograd ArrayBox with value 3.4422848447354477e+17 fin
# d Autograd ArrayBox with value 3.4422848447354477e+17 fin
# d 3.4422848447354477e+17 fin
# p -7.538946561854513e+17 2.3147175530024115e+18
# d Autograd ArrayBox with value -5.489300397063898e+18 fin
# d Autograd ArrayBox with value -5.489300397063898e+18 fin
# [[-9.15280304e+18  1.53960946e+19]
#  [-1.78711467e+55  5.48706065e+55]]
# d Autograd ArrayBox with value -5.489300397063898e+18 fin
# d Autograd ArrayBox with value -5.489300397063898e+18 fin
# d -5.489300397063898e+18 fin
# p 2.0043121009413788e+18 2.572990407233143e+18
# d Autograd ArrayBox with value -1.0172826801582596e+18 fin
# d Autograd ArrayBox with value -1.0172826801582596e+18 fin
# [[6.87989179e+18 1.14293182e+19]
#  [8.52838538e+55 1.09481222e+56]]
# d Autograd ArrayBox with value -1.0172826801582596e+18 fin
# d Autograd ArrayBox with value -1.0172826801582596e+18 fin
# d -1.0172826801582596e+18 fin
# p 6.840578808346085e+18 -2.2279503614260552e+18
# d Autograd ArrayBox with value 1.6222278143640177e+19 fin
# d Autograd ArrayBox with value 1.6222278143640177e+19 fin
# [[ 4.54993736e+19 -2.70488598e+19]
#  [ 1.41619905e+57 -4.61250614e+56]]
# d Autograd ArrayBox with value 1.6222278143640177e+19 fin
# d Autograd ArrayBox with value 1.6222278143640177e+19 fin
# d 1.6222278143640177e+19 fin
# p 7.603840749787448e+18 5.923251787332692e+18
# d Autograd ArrayBox with value 3.006328929827755e+18 fin
# d Autograd ArrayBox with value 3.006328929827755e+18 fin
# [[3.37765409e+19 2.03318292e+19]
#  [2.82568777e+57 2.20115869e+57]]
# d Autograd ArrayBox with value 3.006328929827755e+18 fin
# d Autograd ArrayBox with value 3.006328929827755e+18 fin
# d 3.006328929827755e+18 fin
# p -6.584159699594898e+18 2.0215649366141567e+19
# d Autograd ArrayBox with value -4.794095588400154e+19 fin
# d Autograd ArrayBox with value -4.794095588400154e+19 fin
# [[-7.99362569e+19  1.34462216e+20]
#  [-1.19047833e+58  3.65518055e+58]]
# d Autograd ArrayBox with value -4.794095588400154e+19 fin
# d Autograd ArrayBox with value -4.794095588400154e+19 fin
# d -4.794095588400154e+19 fin
# p 1.7504714819462402e+19 2.247128243683631e+19
# d Autograd ArrayBox with value -8.884466245837784e+18 fin
# d Autograd ArrayBox with value -8.884466245837784e+18 fin
# [[6.00857240e+19 9.98182650e+19]
#  [5.68114522e+58 7.29304191e+58]]
# d Autograd ArrayBox with value -8.884466245837784e+18 fin
# d Autograd ArrayBox with value -8.884466245837784e+18 fin
# d -8.884466245837784e+18 fin
# p 5.974238302704971e+19 -1.945786571383033e+19
# d Autograd ArrayBox with value 1.4167771201559922e+20 fin
# d Autograd ArrayBox with value 1.4167771201559922e+20 fin
# [[ 3.97370030e+20 -2.36231960e+20]
#  [ 9.43394567e+59 -3.07260003e+59]]
# d Autograd ArrayBox with value 1.4167771201559922e+20 fin
# d Autograd ArrayBox with value 1.4167771201559922e+20 fin
# d 1.4167771201559922e+20 fin
# p 6.640835216990971e+19 5.1730882277513585e+19
# d Autograd ArrayBox with value 2.6255856333683528e+19 fin
# d Autograd ArrayBox with value 2.6255856333683528e+19 fin
# [[2.94988348e+20 1.77568589e+20]
#  [1.88231909e+60 1.46629187e+60]]
# d Autograd ArrayBox with value 2.6255856333683528e+19 fin
# d Autograd ArrayBox with value 2.6255856333683528e+19 fin
# d 2.6255856333683528e+19 fin
# p -5.750293969342244e+19 1.7655392933991154e+20
# d Autograd ArrayBox with value -4.186936558074395e+20 fin
# d Autograd ArrayBox with value -4.186936558074395e+20 fin
# [[-6.98125497e+20  1.17432946e+21]
#  [-7.93031737e+60  2.43488194e+61]]
# d Autograd ArrayBox with value -4.186936558074395e+20 fin
# d Autograd ArrayBox with value -4.186936558074395e+20 fin
# d -4.186936558074395e+20 fin
# p 1.5287790796997365e+20 1.9625356275592158e+20
# d Autograd ArrayBox with value -7.759273013595518e+19 fin
# d Autograd ArrayBox with value -7.759273013595518e+19 fin
# [[5.24760322e+20 8.71765561e+20]
#  [3.78446911e+61 4.85822677e+61]]
# d Autograd ArrayBox with value -7.759273013595518e+19 fin
# d Autograd ArrayBox with value -7.759273013595518e+19 fin
# d -7.759273013595518e+19 fin
# p 5.2176174410804455e+20 -1.699358049857628e+20
# d Autograd ArrayBox with value 1.2373461917149993e+21 fin
# d Autograd ArrayBox with value 1.2373461917149993e+21 fin
# [[ 3.47044207e+21 -2.06313832e+21]
#  [ 6.28438010e+62 -2.04679857e+62]]
# d Autograd ArrayBox with value 1.2373461917149993e+21 fin
# d Autograd ArrayBox with value 1.2373461917149993e+21 fin
# d 1.2373461917149993e+21 fin
# p 5.799791688226964e+20 4.5179308212636864e+20
# d Autograd ArrayBox with value 2.2930624289813702e+20 fin
# d Autograd ArrayBox with value 2.2930624289813702e+20 fin
# [[2.57628885e+21 1.55080016e+21]
#  [1.25389832e+63 9.76763678e+62]]
# d Autograd ArrayBox with value 2.2930624289813702e+20 fin
# d Autograd ArrayBox with value 2.2930624289813702e+20 fin
# d 2.2930624289813702e+20 fin
# p -5.022035042056294e+20 1.5419385942441365e+21
# d Autograd ArrayBox with value -3.6566725502422074e+21 fin
# d Autograd ArrayBox with value -3.6566725502422074e+21 fin
# [[-6.09709821e+21  1.02560386e+22]
#  [-5.28274493e+63  1.62198555e+64]]
# d Autograd ArrayBox with value -3.6566725502422074e+21 fin
# d Autograd ArrayBox with value -3.6566725502422074e+21 fin
# d -3.6566725502422074e+21 fin
# p 1.3351634109052483e+21 1.7139858841014963e+21
# d Autograd ArrayBox with value -6.776582411771215e+20 fin
# d Autograd ArrayBox with value -6.776582411771215e+20 fin
# [[4.58300870e+21 7.61358848e+21]
#  [2.52100692e+64 3.23628572e+64]]
# d Autograd ArrayBox with value -6.776582411771215e+20 fin
# d Autograd ArrayBox with value -6.776582411771215e+20 fin
# d -6.776582411771215e+20 fin
# p 4.5568205321072175e+21 -1.4841390233066883e+21
# d Autograd ArrayBox with value 1.0806396972185925e+22 fin
# d Autograd ArrayBox with value 1.0806396972185925e+22 fin
# [[ 3.03092012e+22 -1.80184752e+22]
#  [ 4.18631129e+65 -1.36346558e+65]]
# d Autograd ArrayBox with value 1.0806396972185925e+22 fin
# d Autograd ArrayBox with value 1.0806396972185925e+22 fin
# d 1.0806396972185925e+22 fin
# p 5.065264010882512e+21 3.9457472996930586e+21
# d Autograd ArrayBox with value 2.0026523745332974e+21 fin
# d Autograd ArrayBox with value 2.0026523745332974e+21 fin
# [[2.25000895e+22 1.35439558e+22]
#  [8.35278675e+65 6.50666692e+65]]
# d Autograd ArrayBox with value 2.0026523745332974e+21 fin
# d Autograd ArrayBox with value 2.0026523745332974e+21 fin
# d 2.0026523745332974e+21 fin
# p -4.38600810638681e+21 1.346656309099825e+22
# d Autograd ArrayBox with value -3.193565021640619e+22 fin
# d Autograd ArrayBox with value -3.193565021640619e+22 fin
# [[-5.32491748e+22  8.95713948e+22]
#  [-3.51907656e+66  1.08047832e+67]]
# d Autograd ArrayBox with value -3.193565021640619e+22 fin
# d Autograd ArrayBox with value -3.193565021640619e+22 fin
# d -3.193565021640619e+22 fin
# p 1.1660686344362362e+22 1.496914282546236e+22
# d Autograd ArrayBox with value -5.918346873871468e+21 fin
# d Autograd ArrayBox with value -5.918346873871468e+21 fin
# [[4.00258324e+22 6.64934843e+22]
#  [1.67935732e+67 2.15583705e+67]]
# d Autograd ArrayBox with value -5.918346873871468e+21 fin
# d Autograd ArrayBox with value -5.918346873871468e+21 fin
# d -5.918346873871468e+21 fin
# p 3.97971173554153e+22 -1.2961768949670427e+22
# d Autograd ArrayBox with value 9.437796495628357e+22 fin
# d Autograd ArrayBox with value 9.437796495628357e+22 fin
# [[ 2.64706242e+23 -1.57364848e+23]
#  [ 2.78869227e+68 -9.08266408e+67]]
# d Autograd ArrayBox with value 9.437796495628357e+22 fin
# d Autograd ArrayBox with value 9.437796495628357e+22 fin
# d 9.437796495628357e+22 fin
# p 4.423762245120395e+22 3.4460292485577135e+22
# d Autograd ArrayBox with value 1.749021955326978e+22 fin
# d Autograd ArrayBox with value 1.749021955326978e+22 fin
# [[1.96505150e+23 1.18286510e+23]
#  [5.56417099e+68 4.33438664e+68]]
# d Autograd ArrayBox with value 1.749021955326978e+22 fin
# d Autograd ArrayBox with value 1.749021955326978e+22 fin
# d 1.749021955326978e+22 fin
# p -3.830532234082978e+22 1.1761059886612013e+23
# d Autograd ArrayBox with value -2.7891087887459265e+23 fin
# d Autograd ArrayBox with value -2.7891087887459265e+23 fin
# [[-4.65053132e+23  7.82274238e+23]
#  [-2.34421688e+69  7.19755727e+69]]
# d Autograd ArrayBox with value -2.7891087887459265e+23 fin
# d Autograd ArrayBox with value -2.7891087887459265e+23 fin
# d -2.7891087887459265e+23 fin
# p 1.0183892466721326e+23 1.3073342027350254e+23
# d Autograd ArrayBox with value -5.168804508098518e+22 fin
# d Autograd ArrayBox with value -5.168804508098518e+22 fin
# [[3.49566707e+23 5.80722672e+23]
#  [1.11869626e+70 1.43610107e+70]]
# d Autograd ArrayBox with value -5.168804508098518e+22 fin
# d Autograd ArrayBox with value -5.168804508098518e+22 fin
# d -5.168804508098518e+22 fin
# p 3.4756921819527845e+23 -1.1320196535922653e+23
# d Autograd ArrayBox with value 8.242525508007259e+23 fin
# d Autograd ArrayBox with value 8.242525508007259e+23 fin
# [[ 2.31181924e+24 -1.37435023e+24]
#  [ 1.85767470e+71 -6.05037546e+70]]
# d Autograd ArrayBox with value 8.242525508007259e+23 fin
# d Autograd ArrayBox with value 8.242525508007259e+23 fin
# d 8.242525508007259e+23 fin
# p 3.8635049149082825e+23 3.009599115188904e+23
# d Autograd ArrayBox with value 1.527513131643079e+23 fin
# d Autograd ArrayBox with value 1.527513131643079e+23 fin
# [[1.71618313e+24 1.03305849e+24]
#  [3.70654726e+71 2.88733199e+71]]
# d Autograd ArrayBox with value 1.527513131643079e+23 fin
# d Autograd ArrayBox with value 1.527513131643079e+23 fin
# d 1.527513131643079e+23 fin
# p -3.3454058543536014e+23 1.0271553975708641e+24
# d Autograd ArrayBox with value -2.435875826152249e+24 fin
# d Autograd ArrayBox with value -2.435875826152249e+24 fin
# [[-4.06155431e+24  6.83201356e+24]
#  [-1.56158944e+72  4.79462012e+72]]
# d Autograd ArrayBox with value -2.435875826152249e+24 fin
# d Autograd ArrayBox with value -2.435875826152249e+24 fin
# d -2.435875826152249e+24 fin
# p 8.894130474908577e+23 1.1417639189958346e+24
# d Autograd ArrayBox with value -4.514189622931547e+23 fin
# d Autograd ArrayBox with value -4.514189622931547e+23 fin
# [[3.05295045e+24 5.07175742e+24]
#  [7.45214437e+72 9.56652208e+72]]
# d Autograd ArrayBox with value -4.514189622931547e+23 fin
# d Autograd ArrayBox with value -4.514189622931547e+23 fin
# d -4.514189622931547e+23 fin
# p 3.035505319594185e+24 -9.886524756728771e+23
# d Autograd ArrayBox with value 7.198632305922274e+24 fin
# d Autograd ArrayBox with value 7.198632305922274e+24 fin
# [[ 2.01903369e+25 -1.20029255e+25]
#  [ 1.23748157e+74 -4.03043016e+73]]
# d Autograd ArrayBox with value 7.198632305922274e+24 fin
# d Autograd ArrayBox with value 7.198632305922274e+24 fin
# d 7.198632305922274e+24 fin
# p 3.3742026357734804e+24 2.6284416587400684e+24
# d Autograd ArrayBox with value 1.334057791690693e+24 fin
# d Autograd ArrayBox with value 1.334057791690693e+24 fin
# [[1.49883325e+25 9.02224468e+24]
#  [2.46909963e+74 1.92338310e+74]]
# d Autograd ArrayBox with value 1.334057791690693e+24 fin
# d Autograd ArrayBox with value 1.334057791690693e+24 fin
# d 1.334057791690693e+24 fin
# p -2.9217193973104887e+24 8.970689894708835e+24
# d Autograd ArrayBox with value -2.1273788474564277e+25 fin
# d Autograd ArrayBox with value -2.1273788474564277e+25 fin
# [[-3.54716962e+25  5.96675782e+25]
#  [-1.04024572e+75  3.19391443e+75]]
# d Autograd ArrayBox with value -2.1273788474564277e+25 fin
# d Autograd ArrayBox with value -2.1273788474564277e+25 fin
# d -2.1273788474564277e+25 fin
# p 7.767713294616616e+24 9.971626566439237e+24
# d Autograd ArrayBox with value -3.942479913847481e+24 fin
# d Autograd ArrayBox with value -3.942479913847481e+24 fin
# [[2.66630266e+25 4.42943328e+25]
#  [4.96421215e+75 6.37269527e+75]]
# d Autograd ArrayBox with value -3.942479913847481e+24 fin
# d Autograd ArrayBox with value -3.942479913847481e+24 fin
# d -3.942479913847481e+24 fin
# p 2.6510669135572316e+25 -8.634423568110241e+24
# d Autograd ArrayBox with value 6.286945308877269e+25 fin
# d Autograd ArrayBox with value 6.286945308877269e+25 fin
# [[ 1.76332862e+26 -1.04827880e+26]
#  [ 8.24342733e+76 -2.68485276e+76]]
# d Autograd ArrayBox with value 6.286945308877269e+25 fin
# d Autograd ArrayBox with value 6.286945308877269e+25 fin
# d 6.286945308877269e+25 fin
# p 2.946869145507724e+25 2.295556746589017e+25
# d Autograd ArrayBox with value 1.1651030388565579e+25 fin
# d Autograd ArrayBox with value 1.1651030388565579e+25 fin
# [[1.30901014e+26 7.87960219e+25]
#  [1.64477952e+77 1.28125293e+77]]
# d Autograd ArrayBox with value 1.1651030388565579e+25 fin
# d Autograd ArrayBox with value 1.1651030388565579e+25 fin
# d 1.1651030388565579e+25 fin
# p -2.5516916656050403e+25 7.834576674312734e+25
# d Autograd ArrayBox with value -1.8579521632488043e+26 fin
# d Autograd ArrayBox with value -1.8579521632488043e+26 fin
# [[-3.09793033e+26  5.21108434e+26]
#  [-6.92954965e+77  2.12761161e+78]]
# d Autograd ArrayBox with value -1.8579521632488043e+26 fin
# d Autograd ArrayBox with value -1.8579521632488043e+26 fin
# d -1.8579521632488043e+26 fin
# p 6.7839537543982425e+25 8.708747467512122e+25
# d Autograd ArrayBox with value -3.443175668149494e+25 fin
# d Autograd ArrayBox with value -3.443175668149494e+25 fin
# [[2.32862276e+26 3.86845773e+26]
#  [3.30688740e+78 4.24514204e+78]]
# d Autograd ArrayBox with value -3.443175668149494e+25 fin
# d Autograd ArrayBox with value -3.443175668149494e+25 fin
# d -3.443175668149494e+25 fin
# p 2.3153165750661492e+26 -7.540897553793818e+25
# d Autograd ArrayBox with value 5.490720964355497e+26 fin
# d Autograd ArrayBox with value 5.490720964355497e+26 fin
# [[ 1.54000790e+27 -9.15517168e+26]
#  [ 5.49132171e+79 -1.78850248e+79]]
# d Autograd ArrayBox with value 5.490720964355497e+26 fin
# d Autograd ArrayBox with value 5.490720964355497e+26 fin
# d 5.490720964355497e+26 fin
# p 2.573656267313889e+26 2.0048307936712284e+26
# d Autograd ArrayBox with value 1.0175459411188013e+26 fin
# d Autograd ArrayBox with value 1.0175459411188013e+26 fin
# [[1.14322760e+27 6.88167223e+26]
#  [1.09566241e+80 8.53500823e+79]]
# d Autograd ArrayBox with value 1.0175459411188013e+26 fin
# d Autograd ArrayBox with value 1.0175459411188013e+26 fin
# d 1.0175459411188013e+26 fin
# p -2.2285269291472264e+26 6.842349070821112e+26
# d Autograd ArrayBox with value -1.622647628112046e+27 fin
# d Autograd ArrayBox with value -1.622647628112046e+27 fin
# [[-2.70558597e+27  4.55111483e+27]
#  [-4.61608805e+80  1.41729882e+81]]
# d Autograd ArrayBox with value -1.622647628112046e+27 fin
# d Autograd ArrayBox with value -1.622647628112046e+27 fin
# d -1.622647628112046e+27 fin
# p 5.9247846562140035e+26 7.605808535605982e+26
# d Autograd ArrayBox with value -3.0071069328967137e+26 fin
# d Autograd ArrayBox with value -3.0071069328967137e+26 fin
# [[2.03370909e+27 3.37852819e+27]
#  [2.20286804e+81 2.82788211e+81]]
# d Autograd ArrayBox with value -3.0071069328967137e+26 fin
# d Autograd ArrayBox with value -3.0071069328967137e+26 fin
# d -3.0071069328967137e+26 fin
# p 2.022088094179039e+27 -6.585863603777225e+26
# d Autograd ArrayBox with value 4.7953362447488556e+27 fin
# d Autograd ArrayBox with value 4.7953362447488556e+27 fin
# [[ 1.34497013e+28 -7.99569435e+27]
#  [ 3.65801904e+82 -1.19140281e+82]]
# d Autograd ArrayBox with value 4.7953362447488556e+27 fin
# d Autograd ArrayBox with value 4.7953362447488556e+27 fin
# d 4.7953362447488556e+27 fin
# p 2.247709774416482e+27 1.7509244836681907e+27
# d Autograd ArrayBox with value 8.886765442681402e+26 fin
# d Autograd ArrayBox with value 8.886765442681402e+26 fin
# [[9.98440968e+27 6.01012735e+27]
#  [7.29870544e+82 5.68555700e+82]]
# d Autograd ArrayBox with value 8.886765442681402e+26 fin
# d Autograd ArrayBox with value 8.886765442681402e+26 fin
# d 8.886765442681402e+26 fin
# p -1.9462901183857523e+27 5.975784366303814e+27
# d Autograd ArrayBox with value -1.417143765646606e+28 fin
# d Autograd ArrayBox with value -1.417143765646606e+28 fin
# [[-2.36293094e+28  3.97472864e+28]
#  [-3.07498611e+83  9.44127176e+83]]
# d Autograd ArrayBox with value -1.417143765646606e+28 fin
# d Autograd ArrayBox with value -1.417143765646606e+28 fin
# d -1.417143765646606e+28 fin
# p 5.174426963000826e+27 6.64255378814225e+27
# d Autograd ArrayBox with value -2.62626510448573e+27 fin
# d Autograd ArrayBox with value -2.62626510448573e+27 fin
# [[1.77614542e+28 2.95064688e+28]
#  [1.46743055e+84 1.88378083e+84]]
# d Autograd ArrayBox with value -2.62626510448573e+27 fin
# d Autograd ArrayBox with value -2.62626510448573e+27 fin
# d -2.62626510448573e+27 fin
# p 1.7659961944961288e+28 -5.75178207874428e+27
# d Autograd ArrayBox with value 4.188020088706404e+28 fin
# d Autograd ArrayBox with value 4.188020088706404e+28 fin
# [[ 1.17463336e+29 -6.98306164e+28]
#  [ 2.43677278e+85 -7.93647578e+84]]
# d Autograd ArrayBox with value 4.188020088706404e+28 fin
# d Autograd ArrayBox with value 4.188020088706404e+28 fin
# d 4.188020088706404e+28 fin
# p 1.963043509023205e+28 1.5291747099987358e+28
# d Autograd ArrayBox with value 7.761281023479312e+27 fin
# d Autograd ArrayBox with value 7.761281023479312e+27 fin
# [[8.71991163e+28 5.24896124e+28]
#  [4.86199951e+85 3.78740800e+85]]
# d Autograd ArrayBox with value 7.761281023479312e+27 fin
# d Autograd ArrayBox with value 7.761281023479312e+27 fin
# d 7.761281023479312e+27 fin
# p -1.6997978240162266e+28 5.2189676999738065e+28
# d Autograd ArrayBox with value -1.237666402561904e+29 fin
# d Autograd ArrayBox with value -1.237666402561904e+29 fin
# [[-2.06367223e+29  3.47134018e+29]
#  [-2.04838804e+86  6.28926034e+86]]
# d Autograd ArrayBox with value -1.237666402561904e+29 fin
# d Autograd ArrayBox with value -1.237666402561904e+29 fin
# d -1.237666402561904e+29 fin
# p 4.51910000937304e+28 5.801292607065014e+28
# d Autograd ArrayBox with value -2.2936558469490384e+28 fin
# d Autograd ArrayBox with value -2.2936558469490384e+28 fin
# [[1.55120148e+29 2.57695556e+29]
#  [9.77522199e+86 1.25487205e+87]]
# d Autograd ArrayBox with value -2.2936558469490384e+28 fin
# d Autograd ArrayBox with value -2.2936558469490384e+28 fin
# d -2.2936558469490384e+28 fin
# p 1.5423376300729387e+29 -5.023334686492671e+28
# d Autograd ArrayBox with value 3.6576188546976414e+29 fin
# d Autograd ArrayBox with value 3.6576188546976414e+29 fin
# [[ 1.02586927e+30 -6.09867607e+29]
#  [ 1.62324513e+88 -5.28684733e+87]]
# d Autograd ArrayBox with value 3.6576188546976414e+29 fin
# d Autograd ArrayBox with value 3.6576188546976414e+29 fin
# d 3.6576188546976414e+29 fin
# p 1.714429443773953e+29 1.3355089357142409e+29
# d Autograd ArrayBox with value 6.778336112722268e+28 fin
# d Autograd ArrayBox with value 6.778336112722268e+28 fin
# [[7.61555879e+29 4.58419473e+29]
#  [3.23879891e+88 2.52296465e+88]]
# d Autograd ArrayBox with value 6.778336112722268e+28 fin
# d Autograd ArrayBox with value 6.778336112722268e+28 fin
# d 6.778336112722268e+28 fin
# p -1.4845231012767532e+29 4.557999784422795e+29
# d Autograd ArrayBox with value -1.0809193542418021e+30 fin
# d Autograd ArrayBox with value -1.0809193542418021e+30 fin
# [[-1.80231382e+30  3.03170449e+30]
#  [-1.36452440e+89  4.18956224e+89]]
# d Autograd ArrayBox with value -1.0809193542418021e+30 fin
# d Autograd ArrayBox with value -1.0809193542418021e+30 fin
# d -1.0809193542418021e+30 fin
# p 3.946768413341736e+29 5.0665748424748126e+29
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-240-465db18175aa> in <module>
# ----> 1 xa, ya= level_curve(f1, xs, ys) #partir d'un bon point
#       2 plt.close()
#       3 display_contour(
#       4     f1,
#       5     x=np.linspace(-1.0, 1.5, 100),
#
# <ipython-input-239-93f5486a6a15> in level_curve(f, x0, y0, delta, N, eps)
#       8         return np.array([f(x,y)-0.8,((x-x0)**2+(y-y0)**2-delta**2)**2+(1-d/(np.abs(d)+eps/100))**2])
#       9     print("fb", fbis(x0,y0))
# ---> 10     return (Newton(fbis, x0, y0+0.1))
#      11 #https://zestedesavoir.com/forums/sujet/11587/savoir-si-le-point-est-a-gauche-ou-a-droite-dun-vecteur/
#      12 #(f(x,y)-c, (x,y)-(x0,y0)=d) #deux points possibles
#
# <ipython-input-191-97dc259f7bfb> in Newton(F, x0, y0, eps, N)
#      17         x0, y0 = x, y
#      18     else:
# ---> 19         raise ValueError(f"no convergence in {N} steps.")
#
# ValueError: no convergence in 100 steps.

# %% [markdown]
# ### Bouclage et auto-intersection
#
# L'algorithme précédent est malheureusement susceptible de faire plusieurs fois le tour d'une courbe de niveau donnée.
#
# #### Question 7 + Tâche 4
#
# Proposer une nouvelle implémentation de `level_curve` qui arrête l'algorithme et renvoie les points connus quand le segment formé par les deux derniers points produits intersecte l'un des segments produits auparavant. En étant (raisonnablement) optimiste, doit-t'on prendre la peine de tester l'intersection du dernier segment avec tous les segments déjà produits (ce qui prend du temps ...) ou juste avec le premier ? Pour répondre à cette question, on pourra se demander si les courbes de niveau similaires à celle de la fonction de Rosenbrock passant par le point $(0.5, 0)$ (cf. Exemples de référence) -- c'est-à-dire "auto-intersectantes" -- sont fréquentes ou rares et pourquoi.

# %% [markdown]
# #### Tâche 5
#
# Valider graphiquement le résultat au moyen des exemples de référence.

# %% [markdown]
# ## Post-traitement

# %% [markdown]
# Pour améliorer le rendu des courbes de niveau, il est tentant de diminuer la distance $\delta$ entre deux points consécutifs. Malheureusement, dans des cas d'usage réalistes, il est fréquent que la fonction $f$ soit beaucoup plus complexe que les exemples qui nous avons considérés. Le nombre de fois où cette fonction est appelée est alors le principal facteur qui détermine le temps de calcul des lignes de niveau. On cherche donc dans cette section à améliorer la qualité visuelle des résultats sans faire exploser le nombre d'évaluation de la fonction $f$. On va chercher à résoudre ce problème en reliant les points successifs par des chemins plus "flexibles" que des segments de droites, ayant le potentiel de mieux coller aux lignes de niveau.

# %% [markdown]
# ### Interpolation
#
# #### Question 8
#
# Soit $P_1$ et $P_2$ deux points du plan et $u_1$ et $u_2$ deux vecteurs du plan non nuls.
# On cherche à produire un chemin $\gamma: [0,1] \to \mathbb{R}^2$ continûment différentiable, joignant $P_1$ et $P_2$ ($\gamma(0) = P_1$ et $\gamma(1) = P_2$), tel que $\gamma'(0)$ soit dans la même direction et le même sens que $u_1$ et $\gamma'(1)$ soit dans la même direction et le même sens que $u_2$.
#
# On recherche une telle solution sous la forme
# $\gamma(t) = (x(t), y(t))$ où
# $$
# x(t) = a + bt + ct^2 \; \mbox{ et } \; y(t) = d + et + ft^2
# $$
# et les paramètres réels $a, b, c, d, e, f$ sont à déterminer(*).
#
#
# Déterminer les coefficients $a, b, c, d, e, f$ solutions de ce problème quand ils existent.
# Expliciter si nécessaire les conditions que doivent remplir $P_1$, $P_2$, $u_1$ et $u_2$ pour qu'une solution existe.
#
# (*) Cf. ["Mathematical Typography" de Donald E. Knuth](https://projecteuclid.org/euclid.bams/1183544082) pp. 354-359 (Bull. Amer. Math. Soc. (N.S.), Volume 1, Number 2 (1979), 337-372), pour une classe de chemins interpolants similaire mais plus complexe.

# %% [markdown]
# #### Tâche 6
#
# Implémenter la solution sous la forme d'une fonction `gamma` dont les arguments sont `t`, `P1`, `P2`, `u1` et `u2` et qui renvoie le ou les points $\gamma(t)$ associés. Lorsqu'il n'existe pas de chemin de la forme souhaitée pour les paramètres `P1`, `P2`, `u1` et `u2`, on utilisera comment remplacement de $\gamma$ un chemin rectiligne interpolant linéairement les points $P_1$ et $P_2$.
#
# Pour des raisons de performance, on vectorisera cette fonction par rapport à `t` :
#
#   - en acceptant comme argument `t` des tableaux NumPy (monodimensionels) de nombres flottants et en renvoyant alors un tableau de taille `(2, len(t))` flottants décrivant l'abscisse et l'ordonnée des `len(t)` points $\gamma(t)$ correspondant,
#
#   - en appliquant directement opérateurs et fonctions mathématiques aux tableaux NumPy, sans utiliser de boucle `for`,
#
# On validera ensuite graphiquement l'implémentation sur un exemple où l'on représentera les point $P_1$ et $P_2$, les tangentes associées et le chemin $\gamma$ correspondant.

# %% [markdown]
# ### Intégration
#
# #### Tâche 7
# Intégrer le mécanisme d'interpolation dans (une nouvelle version de) la fonction `level_curve` qui accepte un nouveau paramètre entier `oversampling` (sur-échantillonnage) tel que :
#
#   - si `oversampling == 1`, la fonction `level_curve` fonctionne comme précédemment,
#
#   - si `oversampling > 1`, la fonction `level_curve` introduit dans son résultat `oversampling - 1` points supplémentaires obtenus par interpolations entre chaque couple de points consécutifs obtenus par la méthode de Newton.

# %% [markdown]
# #### Tâche 8
#
# Valider graphiquement le résultat au moyen des exemples de référence.
